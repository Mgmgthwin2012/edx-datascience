# %%
#module 1 - Python Basic
myInt = 5
myInt
# Out:
# 5

# %%
type(myInt)
# Out:
# int

# %%
myFloat = 5.0
myFloat
# Out:
# 5.0

# %%
type(myFloat)
# Out:
# float

# %%
myString = 'Hello World'
myString
# Out:
# 'Hello World'

# %%
myString = "Hello World"
myString
# Out:
# 'Hello World'

# %%
type(myString)
# Out:
# str

# %%
int(myFloat)
# Out:
# 5

# %%
int(myString)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4ff76fde81f2> in <cell line: 1>()
# ----> 1 int(myString)
#
# ValueError: invalid literal for int() with base 10: 'Hello World'

# %%
myBool = True
myBool
# Out:
# True

# %%
type(myBool)
# Out:
# bool
